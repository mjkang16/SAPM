# %%
from Strategy import RL

case_num = 1

for i in range(case_num):
    
    CartPole = RL(max_steps = 1500000, size_action_batch = 64, beta_max_step = 400000, min_distance = 0.2,
                
                batch_size = 64, training_step = 1, copy_step = 1, action_copy_step = 100, scale = 0.01,
                layer_size_Q1 = 400, layer_size_Q2 = 300, learning_rate_Q = 0.0001, learning_rate_A = 0.01,
                
                ending_cond_reward = 10000, save_epi = 200,
                
                Game = 'Hopper-v1', seed_n = 0, file_name = 'APM_Hopper_DPP_(64,64,0.01,0.0001,0.01)')
# Out:
# [2018-11-09 11:28:44,615] Making new env: Hopper-v1
# CASE 1
#   STATE DIM : 11, ACTION DIM : 3
#   Action Particle Method ::: Exp : Softmax
#
# 1           22.988
#                    ( Result : 22.988,  Loss : 0,  Steps : 33,  Global Steps : 33 )
#                    ( Action Batch  ::::  Distance : 1.3475,  Percent : 2.728%(14.137%),  range_out : 0.0% )
# 2           15.724
#                    ( Result : 8.459,  Loss : 0,  Steps : 14,  Global Steps : 47 )
#                    ( Action Batch  ::::  Distance : 1.3475,  Percent : 2.728%(14.137%),  range_out : 0.0% )
# 3           16.187
#                    ( Result : 17.113,  Loss : 0,  Steps : 19,  Global Steps : 66 )
#                    ( Action Batch  ::::  Distance : 1.3475,  Percent : 2.728%(14.137%),  range_out : 0.0% )
# 4           15.078
#                    ( Result : 11.75,  Loss : 0,  Steps : 16,  Global Steps : 82 )
# ...
