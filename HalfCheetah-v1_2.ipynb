# %%
from Strategy import RL

case_num = 1

for i in range(case_num):
    
    CartPole = RL(max_episodes = 1000, size_action_batch = 64, beta_max_step = 400000,
                
                batch_size = 64, training_step = 1, copy_step = 1, action_copy_step = 100, scale = 0.05,
                layer_size_Q1 = 400, layer_size_Q2 = 300, learning_rate_Q = 0.0001, learning_rate_A = 0.01,
                
                ending_cond_reward = 10000, save_epi = 100,
                
                Game = 'HalfCheetah-v1', seed_n = 0, file_name = 'APM_HalfCheetah_Test')
# Out:
# [2018-11-06 18:07:35,756] Making new env: HalfCheetah-v1
# CASE 1
#   STATE DIM : 17, ACTION DIM : 6
#   Action Particle Method ::: Exp : Softmax
#
# 1           -270.428
#                    ( Result : -270.428,  Loss : 0,  Steps : 1000,  Global Steps : 1000 )
#                    ( Action Batch  ::::  Distance : 2.1841,  Percent : 0.0%(0.198%),  range_out : 0.0% )
# 2           -210.338
#                    ( Result : -150.249,  Loss : 0,  Steps : 1000,  Global Steps : 2000 )
#                    ( Action Batch  ::::  Distance : 2.1464,  Percent : 0.0%(0.248%),  range_out : 0.0% )
# 3           -206.384
#                    ( Result : -198.475,  Loss : 0,  Steps : 1000,  Global Steps : 3000 )
#                    ( Action Batch  ::::  Distance : 2.1083,  Percent : 0.0%(0.298%),  range_out : 0.0% )
# 4           -206.093
#                    ( Result : -205.222,  Loss : 0,  Steps : 1000,  Global Steps : 4000 )
# ...
