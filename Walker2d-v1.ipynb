# %%
from Strategy import RL

case_num = 1

for i in range(case_num):
    
    CartPole = RL(max_steps = 1500000, size_action_batch = 64, beta_max_step = 400000,
                
                batch_size = 64, training_step = 1, copy_step = 1, action_copy_step = 100, scale = 0.33,
                layer_size_Q1 = 400, layer_size_Q2 = 300, learning_rate_Q = 0.0001, learning_rate_A = 0.01,
                
                ending_cond_reward = 10000, save_epi = 200,
                
                Game = 'Walker2d-v1', seed_n = 0, file_name = 'APM_Walker_Bounded_(64,64,0.33,0.0001,0.01))')
# Out:
# [2018-10-21 03:17:11,860] Making new env: Walker2d-v1
# CASE 1
#   STATE DIM : 17, ACTION DIM : 6
#   Action Particle Method ::: Exp : Softmax
#
# 1           5.912
#                    ( Result : 5.912,  Loss : 0,  Steps : 21,  Global Steps : 21 )
#                    ( Action Batch  ::::  Distance : 1.9191,  Percent : 0.099%(0.248%),  range_out : 0.0% )
# 2           2.632
#                    ( Result : -0.649,  Loss : 0,  Steps : 30,  Global Steps : 51 )
#                    ( Action Batch  ::::  Distance : 1.9191,  Percent : 0.099%(0.248%),  range_out : 0.0% )
# 3           1.15
#                    ( Result : -1.815,  Loss : 0,  Steps : 22,  Global Steps : 73 )
#                    ( Action Batch  ::::  Distance : 1.9191,  Percent : 0.099%(0.248%),  range_out : 0.0% )
# 4           3.47
#                    ( Result : 10.431,  Loss : 0,  Steps : 24,  Global Steps : 97 )
#                    ( Action Batch  ::::  Distance : 1.9191,  Percent : 0.099%(0.248%),  range_out : 0.0% )
# ...
